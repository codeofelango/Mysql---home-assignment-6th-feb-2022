# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host='127.0.0.1',user='root',passwd='@Elango123')

# %%
cursor = mydb.cursor()

# %%
cursor.execute("create database cardataset")

# %%
cursor.execute('use cardataset')

# %%
cursor.execute('show tables')

# %%
mydb.commit()

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('create table cardataset.car(col1 varchar(50),col2 varchar(50),col3 varchar(50),col4 varchar(50),col5 varchar(50),col6 varchar(50),col7 varchar(50))')

# %%
cursor.execute('DROP TABLE cardataset.car')

# %%
file = open('car.data', 'r')

# %%
 cursor.execute('select * from  cardataset.car')

# %%
cursor.execute('insert into cardataset.car value(vhigh,"vhigh","2","2","small","low","unacc")')

# %%
 cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc')]

# %%
import csv
with open ('car.data','r') as f:
    cardata = csv.reader(f, delimiter = '\n')
    print(cardata)
    for i in cardata:
#             print(i[0].split(','))
            val = i[0].split(',')
#             cursor.execute('insert into ineuron.glassdata value({values})'.format(values = (val)))
            cursor.execute('insert into cardataset.car value( '"'"+str(val[0])+"'"','"'"+str(val[1])+"'"','"'"+str(val[2])+"'"','"'"+str(val[3])+"'"','"'"+str(val[4])+"'"','"'"+str(val[5])+"'"','"'"+str(val[6])+"'"')')
#             cursor.execute('insert into cardataset.car value( '"'"+str(i[0][0])+"',""'"+str(i[0][1])+"'","'"+str(i[0][2])+"'","'"+str(i[0][3])+"'","'"+str(rowi[0][4])+"'","'"+str(rowi[0][5])+"'","'"+str(rowi[0][6])+"'","'"+str(rowi[0][7])+"'")')
# Out:
# ...
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# vhigh
# ...

# %%
 cursor.execute('select * from  cardataset.car')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
# ...

# %%
 cursor.execute('select count(*), col1 from  cardataset.car group by col1')

# %%
cursor.fetchall()
# Out:
# [(433, 'vhigh'), (432, 'high'), (432, 'med'), (432, 'low')]

# %%
 cursor.execute('select * from  cardataset.car where col3 = 4')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %%
 cursor.execute('update cardataset.car set col3 = "8"  where col3 = "2"')

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('drop table cardataset.car')

# %%
cursor.execute('drop database cardataset')
